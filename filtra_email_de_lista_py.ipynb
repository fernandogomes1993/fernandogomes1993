# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandogomes1993/fernandogomes1993/blob/main/filtra_email_de_lista_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# lista de emails fiticios
base_de_dados = ['joao.silva.testes@gmail.com', 'maria.oliveira.demo@gmail.com',
'pedro.santos.fake@gmail.com','matheus.fernandes@hotmail.com','maria.evelyn@hotmail.com',
'teste.usuario01@hotmail.com','exemplo_fake123@hotmail.com','nome.sobrenome.teste@hotmail.com',
'cliente.ficticio99@hotmail.com','demo.user.pro@hotmail.com',
'ana.pereira.dev@gmail.com','lucas.souza.user@gmail.com']



def filtro_de_emails(email, filtro):
  lista_de_email = []

  for item in base_de_dados:
    if filtro in item:
      lista_de_email.append(item)
  return lista_de_email


lista_de_email = filtro_de_emails(base_de_dados,filtro = input('digite o filtro gmail ou hotmail:  '))

for exibir_email in lista_de_email:
  print(exibir_email)
# Out:
# digite o filtro gmail ou hotmail:  gmail
# joao.silva.testes@gmail.com
# maria.oliveira.demo@gmail.com
# pedro.santos.fake@gmail.com
# ana.pereira.dev@gmail.com
# lucas.souza.user@gmail.com
